# %%
import pandas as pd

# %%
df = pd.read_excel('../anketi/бабичи.xlsx')

# %%
df
# Out:
#     Пол  Возраст            Семья                   Другие родственники  \
# 0   NaN      NaN              NaN                                   NaN
# 1     д     17.0  неполная (мать)                               Бабушка
# 2     м     17.0  неполная (мать)          Бабушка, дедушка, сестра (ы)
# 3     д     16.0           полная                                     -
# 4   NaN     15.0  неполная (мать)                               брат(я)
# 5   NaN     16.0           полная                                     -
# 6     м     15.0           полная                                     -
# 7     м     16.0  неполная (мать)                               брат(я)
# 8     м     16.0           полная                                     -
# 9     д     16.0           полная                               брат(я)
# 10    д     16.0           полная                                     -
# 11    д     15.0  неполная (мать)                               брат(я)
# ...
