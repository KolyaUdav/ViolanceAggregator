# %%
import pandas as pd

# %%
df = pd.read_excel('../anketi/бабичи.xlsx')

# %%
df.head()
# Out:
#    Пол  Возраст            Семья           Другие родственники  \
# 0  NaN      NaN              NaN                           NaN
# 1    д     17.0  неполная (мать)                       Бабушка
# 2    м     17.0  неполная (мать)  Бабушка, дедушка, сестра (ы)
# 3    д     16.0           полная                             -
# 4  NaN     15.0  неполная (мать)                       брат(я)
#
#   Средовое окружение Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0                  1          2          3          4         5.0          6
# 1                NaN        NaN        NaN        NaN         NaN        NaN
# 2                NaN        NaN        NaN        NaN         NaN        NaN
# 3                NaN        NaN        NaN        NaN         NaN        NaN
# 4                NaN     иногда        NaN        NaN         NaN        NaN
#
#    ...  Unnamed: 72  Unnamed: 73 Unnamed: 74  Unnamed: 75 Unnamed: 76  \
# ...
